# %%
# 변수(variable)는 처리할 데이터(상수, constant)를 저장하는 기억장소를 말한다.
# 변수명 작성방법
# 영문자(대소문자를 구분한다.), 숫자, 특수문자(_)만 사용할 수 있으며 반드시 문자로 시작해야 하고 예약어는 사용할 수 없다.

# %%
# 파이썬은 c/c++이나 java와 달리 변수 선언시 변수의 자료형을 지정하지 않으며 입력되는 데이터의 타입에 따라서 자동으로 변수의 자료형이 결정된다.
# "="는 같다라는 의미로 사용되지 않고 "=" 오른쪽의 데이터를 "=" 왼쪽의 기억장소에 저장하라는 의미로 사용된다. => 대입문
# "=="와 같이 2개를 연속해서 사용해야 같다로 인식한다.
a = "홍길동"
print(type(a))
a = 100
print(type(a))
a = 185.2
print(type(a))
# True => 참, False => 거짓, 반드시 첫 문자만 대문자로 사용해야 한다.
a = True
print(type(a))

# %%
# 더이상 필요없는 변수는 del 명령으로 삭제할 수 있다.
del a
# print(a) # a라는 변수가 메모리에서 삭제되었으므로 에러가 발생된다.

# %%
# input() 함수로 키보드로 입력하는 데이터를 받을 수 있다. => 무조건 문자열 형태로 입력받는다.
print("이름을 입력하세요 : ", end = "")
name = input()
print("%s님 안녕하세요" % name)

# %%
# input() 함수의 인수로 메시지를 출력할 수 있다.
name = input("이름을 입력하세요 : ")
print("%s님 안녕하세요" % name)

# %%
# input() 함수는 무조건 문자 형태로 데이터를 입력받기때문에 정수나 실수 형태의 데이터를 입력받으려면 입력받은 데이터를 int() 함수나 float() 함수를 사용해서
# 숫자로 변환시켜야 한다.
age = float(input("나이를 입력하세요 : "))
print(type(age))
print("%s님은 %f살 입니다." % (name, age))
print("{}님은 {}살 입니다.".format(name, age))
# "+" 연산자는 문자열과 문자열, 숫자와 숫자의 연산만 가능하다. => 문자열과 숫자를 연산하면 에러가 발생된다.
# 문자열과 문자열에 "+" 연산자를 사용하면 두 문자열을 하나로 이어주는 기능이 실행되고 숫자와 숫자에 "+" 연산자를 사용하면 덧셈이 실행된다.
print("{}님은 내년에 {}살 입니다.".format(name, age + 1))
# Out:
# 나이를 입력하세요 : 20
# <class 'float'>
# 홍길동님은 20.000000살 입니다.
# 홍길동님은 20.0살 입니다.
# 홍길동님은 내년에 21.0살 입니다.

# %%
# split() 메소드를 사용하면 문자열을 구분자를 경계로 분리할 수 있다. => 구분자를 지정하지 않으면 공백이 기본 구분자로 사용된다.
print("Hello Python")
print("Hello Python".split())

name, age = input("이름과 나이를 입력하세요 : ").split()
print("{}님은 {}살 입니다.".format(name, age))
print("{}님은 내년에 {}살 입니다.".format(name, int(age) + 1))
# Out:
# Hello Python
# ['Hello', 'Python']
# 이름과 나이를 입력하세요 : 일지매 17
# 일지매님은 17살 입니다.
# 일지매님은 내년에 18살 입니다.

# %%
# map() 함수를 사용하면 입력받은 데이터를 split() 메소드로 구분하고 일괄적으로 숫자로 변환시킬 수 있다.
# map(자료형, input("메시지").split())
python, java, jsp = map(int, input("세 과목 점수를 입력하세요 : ").split())
print("총점 : {}".format(python + java + jsp))
# Out:
# 세 과목 점수를 입력하세요 : 100 100 100
# 총점 : 300
