# %% [markdown]
# 함수의 구조
# def 함수이름([인수, ...]):
# &nbsp;&nbsp;&nbsp;&nbsp;함수가 실행할 문장
# &nbsp;&nbsp;&nbsp;&nbsp;...
# &nbsp;&nbsp;&nbsp;&nbsp;[return 함수의 결과 값]

# %% [markdown]
# 함수의 실행 순서
# 프로그램에서 함수가 호출되면 호출된 함수로 제어가 넘어간다. => 복귀 주소는 스택에 저장된다.
# 호출된 함수에서 정의한 기능을 실행한 후 함수가 종료되거나 return을 만나면 함수가 호출된 곳으로 되돌아간다. => 스택에 저장된 복귀 주소를 참조해서 돌아간다.
# return이 있으면 return 뒤의 값을 가지고 함수를 호출한 곳으로 돌아가고 return이 없으면 None을 가지고 돌아간다.

# %%
# 가장 일반적인 함수의 모양
# a, b 2개의 데이터를 인수로 넘겨받아 덧셈을 실행한 결과를 return하는 함수
def add(a, b): # 호출당하는 함수의 인수를 가인수라 부른다.
    print("add() 함수가 실행됩니다.")
    result = a + b
    a = 999
    print("가인수 a : {}".format(a))
    return result

# %% [markdown]
# 실인수와 가인수는 독립된 메모리를 사용하기때문에 가인수 값이 변경되더라도 실인수의 값은 변경되지 않는다.
# 실인수와 가인수의 이름은 반드시 같아야 할 필요는 없지만 개수는 반드시 같아야 한다.

# %%
a, b = map(int, input("숫자 2개를 입력하세요 : ").split())
# 함수를 호출할 때는 호출할 함수의 이름을 적으면 된다. => () 안에 적어주는 인수의 개수가 일치해야 한다.
print(add(a, b)) # 함수를 호출하는 부분의 인수를 실인수라 부른다.
print("실인수 a : {}".format(a))
# Out:
# 숫자 2개를 입력하세요 : 5 6
# add() 함수가 실행됩니다.
# 가인수 a : 999
# None
# 실인수 a : 5
