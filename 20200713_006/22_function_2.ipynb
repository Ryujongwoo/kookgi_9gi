# %%
# 인수가 없는 함수, 함수가 처리할 데이터를 넘겨받지 않는 함수
def func1():
    # print("func1() 함수가 실행됩니다. - 1")
    # 함수가 끝나거나 return을 만나면 함수가 호출된곳으로 되돌아간다. => return이 있으면 return 뒤의 값을 가지고 돌아간다.
    return "func1() 함수가 실행됩니다. - 2"

# %%
print(func1())
# Out:
# func1() 함수가 실행됩니다. - 2

# %%
# 결과값(return)이 없는 함수
def func2(a, b):
    print("{} + {} = {}".format(a, b, a + b))

# 파이썬은 함수의 오버로딩이 지원되지 않는다. => 오버로딩 호과를 내려면 가변 인자를 가지는 함수를 만들어 사용하면 된다.
# 오버로딩 => 같은 이름으로 함수를 여러개 만들어 사용할 수 있다.
# 함수 오버로딩은 이름이 같은 함수가 여러개 있을 경우 인수의 개수가 다르면 서로 다른 함수로 취급한다. 만약에 인수의 개수도 같으면 인수의 데이터 타입으로
# 함수를 식별한다.
# 파이썬은 함수의 오버로딩이 지원되지 않기때문에 같은 이름으로 함수를 여러개 만들면 맨 마지막에 정의한 함수만 유효한 함수가되고 앞에서 만든 함수는 뒤에서
# 만든 함수로 덮어쓰기가 된다.

def func2(a, b, c):
    print("{} - {} + {} = {}".format(a, b, c, a - b + c))

# %%
func2(5, 3)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-16-17fadd0d966f> in <module>
# ----> 1 func2(5, 3)
#
# TypeError: func2() missing 1 required positional argument: 'c'

# %%
func2(5, 3, 7)
# Out:
# 5 - 3 + 7 = 9
