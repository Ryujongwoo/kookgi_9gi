# %%
from selectionSorModule import *

# %% [markdown]
# 999가 입력될 때 까지 데이터를 입력받아 정렬하는 프로그램

# %%
data = []
while True:
    m = int(input("정렬할 데이터 입력 : "))
    # 999가 입력되면 무한 루프를 탈출하고 데이터를 정렬한다.
    if m == 999:
        break
    data.append(m)
print(data)

result = selectionSortAsc(data)
print("오름차순 정렬 결과 : {}".format(result))
result = selectionSortDesc(data)
print("내림차순 정렬 결과 : {}".format(result))
# Out:
# 정렬할 데이터 입력 : 9
# 정렬할 데이터 입력 : 3
# 정렬할 데이터 입력 : 4
# 정렬할 데이터 입력 : 9
# 정렬할 데이터 입력 : 1
# 정렬할 데이터 입력 : 999
# [9, 3, 4, 9, 1, 999]
# 오름차순 정렬 결과 : [1, 3, 4, 9, 9, 999]
# 내림차순 정렬 결과 : [999, 9, 9, 4, 3, 1]

# %%
data = []
m = 0
while m != 999:
    m = int(input("정렬할 데이터 입력 : "))
    data.append(m)
del data[len(data) - 1]
# del data[-1]
# data.remove(999)
# data.pop()
print(data)

result = selectionSortAsc(data)
print("오름차순 정렬 결과 : {}".format(result))
result = selectionSortDesc(data)
print("내림차순 정렬 결과 : {}".format(result))
# Out:
# 정렬할 데이터 입력 : 8
# 정렬할 데이터 입력 : 3
# 정렬할 데이터 입력 : 4
# 정렬할 데이터 입력 : 9
# 정렬할 데이터 입력 : 1
# 정렬할 데이터 입력 : 999
# [8, 3, 4, 9, 1]
# 오름차순 정렬 결과 : [1, 3, 4, 8, 9]
# 내림차순 정렬 결과 : [9, 8, 4, 3, 1]
